# %% [markdown]
# # Ejercicio 6

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rc

# %%
data = np.genfromtxt('ns_prob.txt', delimiter = '\t')
plt.plot(data, '.')
plt.show()
